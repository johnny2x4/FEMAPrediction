# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# Info got it from:
#
#
# - https://www.fema.gov/openfema-dataset-disaster-declarations-summaries-v1
# -     https://www.fema.gov/openfema-dataset-disaster-declarations-summaries-v2
# - https://www.fema.gov/openfema-dataset-fema-web-disaster-summaries-v1

# %% [markdown]
# # Disaster Declarations Summaries

# %%
disaster_declar_summ = pd.read_csv('../FEMA_DATA/DisasterDeclarationsSummaries2.csv')

# %%
def clean_info(dataframe):
    #filter only disasters that happened after the year 2000
    greater_than_2000 = dataframe['fyDeclared']  >= 2000
    clean = dataframe[greater_than_2000]

    #filter only disasters that happened in Florida
    florida_state = clean['state'] == 'FL'
    clean_2= clean[florida_state]
    return clean_2

# %%
df_1 = clean_info(disaster_declar_summ)
df_1
# Out:
#       femaDeclarationString  disasterNumber state declarationType  \
# 12877            DR-1306-FL            1306    FL              DR
# 13706            DR-1306-FL            1306    FL              DR
# 13864            DR-1359-FL            1359    FL              DR
# 14154            DR-1306-FL            1306    FL              DR
# 14172            DR-1359-FL            1359    FL              DR
# ...                     ...             ...   ...             ...
# 59029            DR-4545-FL            4545    FL              DR
# 59030            DR-4545-FL            4545    FL              DR
# 59031            DR-4545-FL            4545    FL              DR
# 59032            DR-4545-FL            4545    FL              DR
# 59060            FM-5309-FL            5309    FL              FM
#
#                 declarationDate  fyDeclared incidentType  \
# 12877  1999-10-20T17:30:00.000Z        2000    Hurricane
# 13706  1999-10-20T17:30:00.000Z        2000    Hurricane
# 13864  2001-02-05T22:32:00.000Z        2001     Freezing
# 14154  1999-10-20T17:30:00.000Z        2000    Hurricane
# 14172  2001-02-05T22:32:00.000Z        2001     Freezing
# ...                         ...         ...          ...
# 59029  2020-05-08T19:36:00.000Z        2020   Biological
# 59030  2020-05-08T19:36:00.000Z        2020   Biological
# 59031  2020-05-08T19:36:00.000Z        2020   Biological
# 59032  2020-05-08T19:36:00.000Z        2020   Biological
# 59060  2020-05-14T03:45:00.000Z        2020         Fire
#
#                 declarationTitle  ihProgramDeclared  iaProgramDeclared  ...  \
# 12877  FL-HURRICANE IRENE-DR-REQ                  0                  1  ...
# 13706  FL-HURRICANE IRENE-DR-REQ                  0                  1  ...
# 13864              SEVERE FREEZE                  0                  1  ...
# 14154  FL-HURRICANE IRENE-DR-REQ                  0                  1  ...
# 14172              SEVERE FREEZE                  0                  1  ...
# ...                          ...                ...                ...  ...
# 59029          COVID-19 PANDEMIC                  0                  0  ...
# 59030          COVID-19 PANDEMIC                  0                  0  ...
# 59031          COVID-19 PANDEMIC                  0                  0  ...
# 59032          COVID-19 PANDEMIC                  0                  0  ...
# 59060           36TH AVENUE FIRE                  0                  0  ...
#
#                 incidentEndDate  disasterCloseoutDate fipsStateCode  \
# 12877  1999-10-24T04:00:00.000Z                   NaN            12
# 13706  1999-10-24T04:00:00.000Z                   NaN            12
# 13864  2001-01-25T05:00:00.000Z                   NaN            12
# 14154  1999-10-24T04:00:00.000Z                   NaN            12
# 14172  2001-01-25T05:00:00.000Z                   NaN            12
# ...                         ...                   ...           ...
# 59029                       NaN                   NaN            12
# 59030                       NaN                   NaN            12
# 59031                       NaN                   NaN            12
# 59032                       NaN                   NaN            12
# 59060                       NaN                   NaN            12
#
#       fipsCountyCode placeCode                designatedArea  \
# 12877             51     99051               Hendry (County)
# 13706              9     99009              Brevard (County)
# 13864             97     99097              Osceola (County)
# 14154             93     99093           Okeechobee (County)
# 14172             57     99057         Hillsborough (County)
# ...              ...       ...                           ...
# 59029              0     32125  Hollywood Indian Reservation
# 59030              0     65033   Seminole Indian Trust Lands
# 59031              0     33260  Immokalee Indian Reservation
# 59032              0     71038             Tampa Reservation
# 59060             21     99021              Collier (County)
#
#        declarationRequestNumber                              hash  \
# 12877                     99139  0e674d2e56e7d0aa4b84d0548ba5b999
# 13706                     99139  bf6b9df5737e9371f713926fc52573b6
# 13864                      1009  1af6ebe215644481a55ba101d824903c
# 14154                     99139  06fba712ba65f75acdf71b50c4eaa439
# 14172                      1009  eda258a18651fa5ec3e1fd57ffc2589f
# ...                         ...                               ...
# 59029                     20175  2472f7f179334501c8e61d7ebdd0faf7
# 59030                     20175  47694bdd5e9200899d3f7587f5c53296
# 59031                     20175  c5db47e8f327e13d344710f74a0be9d9
# 59032                     20175  1c2e2e74baff84c45e4e912c718816b4
# 59060                     20182  274224991e24a2e15ab06774382ef578
#
#                     lastRefresh                        id
# 12877  2019-07-26T18:49:45.333Z  5d1bcebbd5b39c032f2640b6
# 13706  2019-07-26T18:49:45.336Z  5d1bcebcd5b39c032f2641ae
# 13864  2019-07-26T18:49:46.149Z  5d1bcebcd5b39c032f2643da
# 14154  2019-07-26T18:49:45.338Z  5d1bcebbd5b39c032f264061
# 14172  2019-07-26T18:49:46.088Z  5d1bcebcd5b39c032f26443e
# ...                         ...                       ...
# 59029  2020-05-08T20:08:49.482Z  5eb5bc51d7f69950ebb8e18e
# 59030  2020-05-08T20:08:49.484Z  5eb5bc51d7f69950ebb8e18f
# 59031  2020-05-08T20:08:49.485Z  5eb5bc51d7f69950ebb8e190
# 59032  2020-05-08T20:08:49.486Z  5eb5bc51d7f69950ebb8e191
# 59060  2020-05-14T14:09:02.426Z  5ebd50fed7f69950ebda0428
#
# [1303 rows x 23 columns]

# %% [markdown]
# # FEMA WEB Disaster Summaries

# %%
web_disaster_summ = pd.read_csv('../FEMA_DATA/FemaWebDisasterSummaries.csv')

# %%
web_disaster_summ
# Out:
#       disasterNumber  totalNumberIaApproved  totalAmountIhpApproved  \
# 0               1258                    NaN                     NaN
# 1               1268                    NaN                     NaN
# 2               1241                    NaN                     NaN
# 3               1265                    NaN                     NaN
# 4               1247                    NaN                     NaN
# ...              ...                    ...                     ...
# 3152            4556                    NaN                     NaN
# 3153            4554                    NaN                     NaN
# 3154            4555                    NaN                     NaN
# 3155            5320                    NaN                     NaN
# 3156            5321                    NaN                     NaN
#
#       totalAmountHaApproved  totalAmountOnaApproved  totalObligatedAmountPa  \
# 0                       NaN                     NaN            9.574047e+06
# 1                       NaN                     NaN            7.219793e+05
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN            6.970269e+06
# 4                       NaN                     NaN            6.110490e+08
# ...                     ...                     ...                     ...
# 3152                    NaN                     NaN                     NaN
# 3153                    NaN                     NaN                     NaN
# 3154                    NaN                     NaN                     NaN
# 3155                    NaN                     NaN                     NaN
# 3156                    NaN                     NaN                     NaN
#
#       totalObligatedAmountCatAb  totalObligatedAmountCatC2g  \
# 0                  1.178287e+06                8.395760e+06
# 1                  4.392952e+04                6.553987e+05
# 2                           NaN                         NaN
# 3                  2.590192e+06                4.349918e+06
# 4                  2.101725e+08                4.008765e+08
# ...                         ...                         ...
# 3152                        NaN                         NaN
# 3153                        NaN                         NaN
# 3154                        NaN                         NaN
# 3155                        NaN                         NaN
# 3156                        NaN                         NaN
#
#                     paLoadDate iaLoadDate  totalObligatedAmountHmgp  \
# 0     2020-07-21T00:00:00.000Z        NaN                 2546649.0
# 1     2020-07-21T00:00:00.000Z        NaN                  120352.0
# 2                          NaN        NaN                  302741.0
# 3     2020-07-21T00:00:00.000Z        NaN                 1319820.0
# 4     2020-07-21T00:00:00.000Z        NaN               220712228.0
# ...                        ...        ...                       ...
# 3152                       NaN        NaN                       0.0
# 3153                       NaN        NaN                       0.0
# 3154                       NaN        NaN                       0.0
# 3155                       NaN        NaN                       0.0
# 3156                       NaN        NaN                       0.0
#
#                                   hash               lastRefresh  \
# 0     de6f338830b3938f4997c6a187da9d78  2020-07-21T11:55:48.121Z
# 1     6679fee8a9945c16e999953252512fe3  2020-07-21T11:55:26.027Z
# 2     cdb3511d86a8653c09a3f67907919323  2020-06-10T05:42:28.848Z
# 3     efb0388f7ae4e21a249013e29bbe43ed  2020-07-21T11:55:26.023Z
# 4     6bdabac33da050175755007f8cfcec20  2020-07-21T11:55:48.115Z
# ...                                ...                       ...
# 3152  dbc03d44f29553eca02c3bc5eb1cc214  2020-07-10T23:02:28.048Z
# 3153  a12ecb56095dc2471cbb11fcbf98faa3  2020-07-11T23:02:31.809Z
# 3154  ac528118acd962ce6cecee82ee16bc5d  2020-07-11T23:02:31.813Z
# 3155  da8f8490e65e5c05b59b5c8c82e962e5  2020-07-13T23:02:43.564Z
# 3156  0686bc4414185bc4b73edc0f2dee1f4d  2020-07-16T23:02:40.558Z
#
#                             id
# 0     5aa2d583cb4f0f7020b17e82
# 1     5aa2d583cb4f0f7020b17e87
# 2     5aa2d583cb4f0f7020b17e8c
# 3     5aa2d583cb4f0f7020b17e91
# 4     5aa2d583cb4f0f7020b17e96
# ...                        ...
# 3152  5f08f3841dbf327060c5d723
# 3153  5f0a45077b00015372096312
# 3154  5f0a45077b00015372096313
# 3155  5f0ce813c5b6f91b0f1fba52
# 3156  5f10dc9031c4713e6078eee7
#
# [3157 rows x 14 columns]

# %% [markdown]
# # MERGE TABLES

# %%
#Merge the 2 dataframes on disasterNumber

merge2 = pd.merge(df_1,web_disaster_summ, on = 'disasterNumber', how = 'inner')
merge2
# Out:
#      femaDeclarationString  disasterNumber state declarationType  \
# 0               DR-1306-FL            1306    FL              DR
# 1               DR-1306-FL            1306    FL              DR
# 2               DR-1306-FL            1306    FL              DR
# 3               DR-1306-FL            1306    FL              DR
# 4               DR-1306-FL            1306    FL              DR
# ...                    ...             ...   ...             ...
# 1263            DR-4545-FL            4545    FL              DR
# 1264            DR-4545-FL            4545    FL              DR
# 1265            DR-4545-FL            4545    FL              DR
# 1266            DR-4545-FL            4545    FL              DR
# 1267            FM-5309-FL            5309    FL              FM
#
#                declarationDate  fyDeclared incidentType  \
# 0     1999-10-20T17:30:00.000Z        2000    Hurricane
# 1     1999-10-20T17:30:00.000Z        2000    Hurricane
# 2     1999-10-20T17:30:00.000Z        2000    Hurricane
# 3     1999-10-20T17:30:00.000Z        2000    Hurricane
# 4     1999-10-20T17:30:00.000Z        2000    Hurricane
# ...                        ...         ...          ...
# 1263  2020-05-08T19:36:00.000Z        2020   Biological
# 1264  2020-05-08T19:36:00.000Z        2020   Biological
# 1265  2020-05-08T19:36:00.000Z        2020   Biological
# 1266  2020-05-08T19:36:00.000Z        2020   Biological
# 1267  2020-05-14T03:45:00.000Z        2020         Fire
#
#                declarationTitle  ihProgramDeclared  iaProgramDeclared  ...  \
# 0     FL-HURRICANE IRENE-DR-REQ                  0                  1  ...
# 1     FL-HURRICANE IRENE-DR-REQ                  0                  1  ...
# 2     FL-HURRICANE IRENE-DR-REQ                  0                  1  ...
# 3     FL-HURRICANE IRENE-DR-REQ                  0                  1  ...
# 4     FL-HURRICANE IRENE-DR-REQ                  0                  1  ...
# ...                         ...                ...                ...  ...
# 1263          COVID-19 PANDEMIC                  0                  0  ...
# 1264          COVID-19 PANDEMIC                  0                  0  ...
# 1265          COVID-19 PANDEMIC                  0                  0  ...
# 1266          COVID-19 PANDEMIC                  0                  0  ...
# 1267           36TH AVENUE FIRE                  0                  0  ...
#
#       totalAmountOnaApproved  totalObligatedAmountPa  \
# 0                        NaN            1.062616e+08
# 1                        NaN            1.062616e+08
# 2                        NaN            1.062616e+08
# 3                        NaN            1.062616e+08
# 4                        NaN            1.062616e+08
# ...                      ...                     ...
# 1263                     NaN                     NaN
# 1264                     NaN                     NaN
# 1265                     NaN                     NaN
# 1266                     NaN                     NaN
# 1267                     NaN                     NaN
#
#      totalObligatedAmountCatAb totalObligatedAmountCatC2g  \
# 0                  32644798.12                72246572.61
# 1                  32644798.12                72246572.61
# 2                  32644798.12                72246572.61
# 3                  32644798.12                72246572.61
# 4                  32644798.12                72246572.61
# ...                        ...                        ...
# 1263                       NaN                        NaN
# 1264                       NaN                        NaN
# 1265                       NaN                        NaN
# 1266                       NaN                        NaN
# 1267                       NaN                        NaN
#
#                     paLoadDate  iaLoadDate  totalObligatedAmountHmgp  \
# 0     2020-07-21T00:00:00.000Z         NaN                21423043.0
# 1     2020-07-21T00:00:00.000Z         NaN                21423043.0
# 2     2020-07-21T00:00:00.000Z         NaN                21423043.0
# 3     2020-07-21T00:00:00.000Z         NaN                21423043.0
# 4     2020-07-21T00:00:00.000Z         NaN                21423043.0
# ...                        ...         ...                       ...
# 1263                       NaN         NaN                       0.0
# 1264                       NaN         NaN                       0.0
# 1265                       NaN         NaN                       0.0
# 1266                       NaN         NaN                       0.0
# 1267                       NaN         NaN                       0.0
#
#                                 hash_y             lastRefresh_y  \
# 0     d4b698032537654f875f3f3284fa9a54  2020-07-21T11:55:26.149Z
# 1     d4b698032537654f875f3f3284fa9a54  2020-07-21T11:55:26.149Z
# 2     d4b698032537654f875f3f3284fa9a54  2020-07-21T11:55:26.149Z
# 3     d4b698032537654f875f3f3284fa9a54  2020-07-21T11:55:26.149Z
# 4     d4b698032537654f875f3f3284fa9a54  2020-07-21T11:55:26.149Z
# ...                                ...                       ...
# 1263  5a2657b1c1420778b0dbfc57f03c8e40  2020-06-02T13:22:22.113Z
# 1264  5a2657b1c1420778b0dbfc57f03c8e40  2020-06-02T13:22:22.113Z
# 1265  5a2657b1c1420778b0dbfc57f03c8e40  2020-06-02T13:22:22.113Z
# 1266  5a2657b1c1420778b0dbfc57f03c8e40  2020-06-02T13:22:22.113Z
# 1267  ce4500df75230b6348eae6ce51c89f17  2020-06-02T13:22:22.689Z
#
#                           id_y
# 0     5aa2d583cb4f0f7020b17f25
# 1     5aa2d583cb4f0f7020b17f25
# 2     5aa2d583cb4f0f7020b17f25
# 3     5aa2d583cb4f0f7020b17f25
# 4     5aa2d583cb4f0f7020b17f25
# ...                        ...
# 1263  5eb5e654d7f69950ebb9d1c4
# 1264  5eb5e654d7f69950ebb9d1c4
# 1265  5eb5e654d7f69950ebb9d1c4
# 1266  5eb5e654d7f69950ebb9d1c4
# 1267  5ebdcf5dd7f69950ebde1a07
#
# [1268 rows x 36 columns]

# %% [markdown]
# # POSTGRESQL

# %%
engine = create_engine('postgresql://postgres:newPassword@localhost:5432/fema')
df_1.to_sql('disaster', engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-390fb6c05cb0> in <module>
#       1 engine = create_engine('postgresql://postgres:newPassword@localhost:5432/fema')
# ----> 2 df_1.to_sql('disaster', engine)
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/pandas/io/sql.py in create(self)
#     644         if self.exists():
#     645             if self.if_exists == "fail":
# --> 646                 raise ValueError(f"Table '{self.name}' already exists.")
#     647             elif self.if_exists == "replace":
#     648                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'disaster' already exists.
